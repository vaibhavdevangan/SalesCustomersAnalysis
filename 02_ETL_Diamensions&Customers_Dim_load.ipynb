# %%
import pandas as pd

df = pd.read_csv("Sample_ Superstore.csv")
df.head()
df.shape
# Out:
# (9994, 19)

# %%
pip install sqlalchemy psycopg2-binary pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Connect to PostgreSQL

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg2://postgres:new_password@localhost:5432/Superstore_db")

# %%
engine = create_engine("postgresql://postgres:new_password@localhost:5432/Superstore_db")

# %%
engine.connect()

# %%
# Further data cleaning and preprocessing steps would go here
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg2://postgres:new_password@localhost:5432/Superstore_db")

# Test connection
connection = engine.connect()
print("Connection successful")
# Out:
# Connection successful

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:new_password@127.0.0.1:5432/Superstore_db"
)

# Test connection
connection = engine.connect()
print("Connection successful")
# Out:
# Connection successful

# %% [markdown]
# ### Verify dataset loading in Python

# %%
import pandas as pd

df = pd.read_csv("Sample_ Superstore.csv")  # exact filename
print(df.shape)
print(df.head(2))
# Out:
# (9994, 19)
#    Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11-08-2016  11-11-2016  Second Class    CG-12520
# 1       2  CA-2016-152156  11-08-2016  11-11-2016  Second Class    CG-12520
#
#     Segment        Country       City     State Region       Product ID  \
# 0  Consumer  United States  Henderson  Kentucky  South  FUR-BO-10001798
# 1  Consumer  United States  Henderson  Kentucky  South  FUR-CH-10000454
#
#     Category Sub-Category                                       Product Name  \
# 0  Furniture    Bookcases                  Bush Somerset Collection Bookcase
# 1  Furniture       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...
#
#     Sales  Quantity  Discount    Profit
# 0  261.96         2       0.0   41.9136
# 1  731.94         3       0.0  219.5820

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales',
#        'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 1          2  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 2          3  CA-2016-138688  06-12-2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9993    9994  CA-2017-119914  05-04-2017  05-09-2017    Second Class
#
#      Customer ID    Segment        Country             City       State  \
# ...

# %%
df.shape
# Out:
# (9994, 19)

# %%
df.describe()
# Out:
#             Row ID         Sales     Quantity     Discount       Profit
# count  9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   4997.500000    229.858001     3.789574     0.156203    28.656896
# std    2885.163629    623.245101     2.225110     0.206452   234.260108
# min       1.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    2499.250000     17.280000     2.000000     0.000000     1.728750
# 50%    4997.500000     54.490000     3.000000     0.200000     8.666500
# 75%    7495.750000    209.940000     5.000000     0.200000    29.364000
# max    9994.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ### Select customer-related columns
# ### Loading dim_customer to Database

# %%
dim_customer = df[
    ["Customer ID", "Segment", "City", "State", "Country"]
].drop_duplicates()
dim_customer.shape
# Out:
# (4688, 5)

# %%
dim_customer.columns
# Out:
# Index(['Customer ID', 'Segment', 'City', 'State', 'Country'], dtype='object')

# %%
dim_customer
# Out:
#      Customer ID    Segment             City           State        Country
# 0       CG-12520   Consumer        Henderson        Kentucky  United States
# 2       DV-13045  Corporate      Los Angeles      California  United States
# 3       SO-20335   Consumer  Fort Lauderdale         Florida  United States
# 5       BH-11710   Consumer      Los Angeles      California  United States
# 12      AA-10480   Consumer          Concord  North Carolina  United States
# ...          ...        ...              ...             ...            ...
# 9986    ML-17410   Consumer      Los Angeles      California  United States
# 9987    RA-19885  Corporate           Athens         Georgia  United States
# 9989    TB-21400   Consumer            Miami         Florida  United States
# 9990    DB-13060   Consumer       Costa Mesa      California  United States
# 9993    CC-12220   Consumer      Westminster      California  United States
#
# [4688 rows x 5 columns]

# %% [markdown]
# ### Renaming the Columns

# %%
dim_customer.columns = [
    "customer_id",
    "segment",
    "city",
    "state",
    "country"
]

# %%
dim_customer.shape
# Out:
# (4688, 5)

# %%
dim_customer["customer_id"].isna().sum()
# Out:
# 0

# %%
dim_customer["customer_id"].nunique()
# Out:
# 793

# %%
dim_customer_clean = (
    dim_customer
    .sort_values("customer_id")
    .drop_duplicates(subset="customer_id", keep="first")
)
dim_customer_clean.shape
# Out:
# (793, 5)

# %%
dim_customer_clean["customer_id"].nunique()
# Out:
# 793

# %% [markdown]
# ### load dim_customer_clean to database

# %%
dim_customer_clean.to_sql(
    "dim_customer",
    engine,
    if_exists="append",
    index=False
)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:2125, in Connection._exec_insertmany_context(self, dialect, context)
#    2124     else:
# -> 2125         dialect.do_execute(
#    2126             cursor,
#    2127             sub_stmt,
#    2128             sub_params,
#    2129             context,
#    2130         )
#    2132 except BaseException as e:
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# UniqueViolation: duplicate key value violates unique constraint "dim_customer_pkey"
# ...

# %% [markdown]
# ## dim_customer loaded successfully to Database

# %%
# Keep only unique customers in your new DataFrame
dim_customer_unique = dim_customer_clean.drop_duplicates(subset=['customer_id'])

# Fetch existing customer_ids from DB
existing_ids = pd.read_sql("SELECT customer_id FROM dim_customer", engine)

# Filter out already existing customers
dim_customer_to_insert = dim_customer_unique[
    ~dim_customer_unique['customer_id'].isin(existing_ids['customer_id'])
]

# Insert only new rows
dim_customer_to_insert.to_sql(
    'dim_customer',
    engine,
    if_exists='append',
    index=False
)
# Out:
# 0
